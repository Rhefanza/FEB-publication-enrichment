# %%
import pandas as pd
df=pd.read_excel('Publikasi internasional.xlsx')
df.head()
# Out:
#    No                                              Title  \
# 0   1  Ethnic identity and internal migration decisio...
# 1   2  The role of service quality within Indonesian ...
# 2   3  Developing Islamic crowdfunding website platfo...
# 3   4  Developing Islamic crowdfunding website platfo...
# 4   5  Developing Islamic crowdfunding website platfo...
#
#                        Authors                                  Journal  \
# 0             ILMIAWAN AUWALIN  Journal of Ethnic and Migration Studies
# 1           BADRI MUNIR SUKOCO             Journal of Islamic Marketing
# 2  MUHAMAD NAFIK HADI RYANDONO             Journal of Islamic Marketing
# 3           ACHSANIA HENDRATMI             Journal of Islamic Marketing
# 4      PUJI SUCIA SUKMANINGRUM             Journal of Islamic Marketing
#
#   SCOPUS Q                Tahun     Volume / Issue  \
# 0        ?  2019-01-11 00:00:00  Vol. 14, Issue 13
# 1        ?  2020-01-14 00:00:00   Vol. 11, Issue 1
# ...

# %%
df.replace('?', pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# No                     0
# Title                  0
# Authors                0
# Journal                9
# SCOPUS Q            2153
# Tahun                  2
# Volume / Issue        96
# LINK DOI/ARTIKEL      54
# SCOPUS SITASI       2153
# dtype: int64

# %%
df.shape
# Out:
# (2153, 9)
